# %% [markdown]
# <a href="https://colab.research.google.com/github/tayeb123123/Shakespeare-LLM/blob/main/Shakespeare_LLM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim

# %%
class MultiHeadSelfAttention(nn.Module):
  def __init__(self, num_heads, d_model):
    super().__init__()
    self.Wq = nn.Linear(d_model, d_model)
    self.Wk = nn.Linear(d_model, d_model)
    self.Wv = nn.Linear(d_model, d_model)
    self.Wo = nn.Linear(d_model, d_model)
    self.num_heads = num_heads
  def forward(self, x):
    batch_size, seq_len, d_model = x.shape[0], x.shape[1], x.shape[2]
    num_heads, d_head = self.num_heads, d_model // self.num_heads
    Q = self.Wq(x).reshape(batch_size, seq_len, num_heads, d_head).transpose(1,2) # (batch_size, seq_len, d_model) -> (batch, size, num_heads, seq_len, d_head)
    K = self.Wk(x).reshape(batch_size, seq_len, num_heads, d_head).transpose(1,2) # (batch_size, seq_len, d_model) -> (batch, size, num_heads, seq_len, d_head)
    V = self.Wv(x).reshape(batch_size, seq_len, num_heads, d_head).transpose(1,2) # (batch_size, seq_len, d_model) -> (batch, size, num_heads, seq_len, d_head)

    mask = torch.ones(seq_len, seq_len, device=x.device, dtype=torch.bool)
    mask = torch.tril(mask)

    attn_scores = Q @ K.transpose(2, 3) / d_head**0.5
    attn_scores = torch.masked_fill(attn_scores, ~mask, -1e9)
    attn_weights = F.softmax(attn_scores, dim = 1)
    context = attn_weights @ V

    context = context.transpose(1,2).reshape(batch_size, seq_len, d_model)
    x = self.Wo(context)
    return x


class FFN(nn.Module):
  def __init__(self, d_model):
    super().__init__()
    self.W1 = nn.Linear(d_model, 4 * d_model)
    self.W2 = nn.Linear(4 * d_model, d_model)
  def forward(self, x):
    x = F.gelu(self.W1(x))
    x = self.W2(x)
    return x


class TransformerBlock(nn.Module):
  def __init__(self, num_heads, d_model):
    super().__init__()
    self.ln1 = nn.LayerNorm(d_model)
    self.mhsa = MultiHeadSelfAttention(num_heads, d_model)
    self.ln2 = nn.LayerNorm(d_model)
    self.ffn = FFN(d_model)
  def forward(self,x):
    x = x + self.mhsa(self.ln1(x))
    x = x + self.ffn(self.ln2(x))
    return x


class Transformer(nn.Module):
  def __init__(self, vocab_size, d_model, n_layers, num_heads, seq_len):
    super().__init__()
    self.embedding = nn.Embedding(vocab_size, d_model)
    self.pos_embedding = nn.Embedding(seq_len, d_model)
    self.transformer_blocks = nn.ModuleList([TransformerBlock(num_heads, d_model) for _ in range(n_layers)])
    self.ln = nn.LayerNorm(d_model)
    self.out_proj = nn.Linear(d_model, vocab_size)
    self.seq_len = seq_len
  def forward(self, x):
    batch_size, current_seq_len = x.shape
    embs = self.embedding(x)
    pos_embs = self.pos_embedding(torch.arange(x.size(1), device=x.device, dtype=torch.long))
    x = embs + pos_embs
    #applies each transformer block
    for transformer_block in (self.transformer_blocks):
      x = transformer_block(x)
    x = self.ln(x)
    x = self.out_proj(x)
    return x

# %%
from torch.utils.data import Dataset, DataLoader

vocab_size = 65
d_model = 96
n_layers = 4
num_heads = 4
seq_len = 32
batch_size = 16
lr=1e-4
num_epochs = 20
device = "cuda" if torch.cuda.is_available() else "cpu"

with open("/content/shakespeare.txt") as f:
    text_corpus = f.read()

char2token = {c:i for i, c in enumerate(sorted(set(text_corpus)))}
token2char = {i:c for c, i in char2token.items()}

def tokenize(string):
    return [char2token[c] for c in string]
def decode(tokens):
    return "".join([token2char[token] for token in tokens])

text_tokens = tokenize(text_corpus)

labels = text_tokens[1:]
inputs = text_tokens[:-1]
trunc_len = len(inputs) - len(inputs) % seq_len
labels = torch.tensor(labels[:trunc_len]).reshape(-1, seq_len)
inputs = torch.tensor(inputs[:trunc_len]).reshape(-1, seq_len)

class ShakespeareDataset(Dataset):
    def __init__(self, inputs, labels):
        super().__init__()
        self.inputs = inputs
        self.labels = labels
    def __len__(self):
        return len(self.inputs)
    def __getitem__(self, idx):
        return self.inputs[idx], self.labels[idx]

dataset = ShakespeareDataset(inputs, labels)
dataloader = DataLoader(dataset, batch_size=batch_size, shuffle=True)

model = Transformer(vocab_size, d_model, n_layers, num_heads, seq_len).to(device)
optimizer = optim.Adam(model.parameters(), lr=lr)
loss_fn = nn.CrossEntropyLoss()

@torch.no_grad()
def generate(prompt, num_tokens):
    tokens = tokenize(prompt)
    tokens = torch.tensor([tokens], device=device) #(batch_dim, len_of_seq)
    for _ in range(num_tokens):
        # Ensure the input sequence length is at most seq_len
        input_tokens = tokens[:, -seq_len:]
        logits = model(input_tokens) #(batch_dim, seq_len, vocab_size)
        probs = F.softmax(logits, dim=-1)[:, -1, :] #(batch_dim, seq_len, vocab_size) -> (batch_dim, vocab_size)
        next_token = torch.multinomial(probs, num_samples=1) #(batch_dim, 1)
        tokens = torch.cat([tokens, next_token], dim=-1)
    return decode(tokens[0].cpu().tolist())


for epoch in range(num_epochs):
    for batch_idx, batch in enumerate(dataloader):
        if batch_idx % 500 == 0:
            print("\n" + generate(prompt="\n", num_tokens=1000) + "\n")
        inputs, labels = batch[0].to(device), batch[1].to(device)
        logits = model(inputs) #inputs: (batch_size, seq_len) -> (batch_size, seq_len, vocab_size); labels: (batch_size, seq_len)
        loss = loss_fn(logits.reshape(-1, vocab_size), labels.reshape(-1))
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        if batch_idx % 10 == 0:
            print(f"Epoch {epoch}, batch {batch_idx}: loss={loss.item()}")
# Out:
# Streaming output truncated to the last 5000 lines.
# 'es'd leap dil ad askedme tootaingedss begbe's w-lighitwle bam lare,
# BitPld dery.
#
# VIOGBOGLELETEUTES:L:
# Thang thenouis tht!
#
# AllBAnd tind, grethe gen'sts Ridgs hat weenrapisst that ie stndes wind nomy hes Anc lild ier:
# ED cut:
# Gorr l aenand we ser agange Bst kneinge drherseres nge cird,nop her, Bibnoronnass y. thaw I nerlly, ne line noun sith galk icear:
# Pel An
# AishDU boust 'derh shO and
# As gvof thees:
# Serudon d te tiond tnnd fod? nig:
# Lse Budneg ady cs;
# Wand IOdoy Con  th rethas re rengo ghes
# A:
# Aon?awun. s. ballt gef:
# LUFonCll gEungt, yoy ers.
# Sar garr I'les prtar'd cut kend, nawindce
# Foou gas Efaging lfig
#
# An gond tgenghict Thim wirer tine oud 'ndg;
#
# wild:
# And Coer faco'd, my, ano hand yox:
# TI nke has Hove yowigs, cao dis sithaly rand wimy los yodgr bll
#
# BLLLA--ULE gol, Thesd tor thes, hedodrlll d, haunds cildomy do shis ge aj theG angling.
#
# WAEMALCAng Tgir se moul 'dil he, leiad e Ery man
# Honge coery ls rourd gn'ghe's tog ly.
#
# IOLO:
# AUC doisti
#
# Epoch 7, batch 1500: loss=0.1338060349225998
# Epoch 7, batch 1510: loss=0.11452583968639374
# Epoch 7, batch 1520: loss=0.14695484936237335
# Epoch 7, batch 1530: loss=0.1512226164340973
# Epoch 7, batch 1540: loss=0.12193873524665833
# Epoch 7, batch 1550: loss=0.11372818797826767
# Epoch 7, batch 1560: loss=0.1551034152507782
# Epoch 7, batch 1570: loss=0.14597956836223602
# Epoch 7, batch 1580: loss=0.1521972417831421
# Epoch 7, batch 1590: loss=0.17846107482910156
# Epoch 7, batch 1600: loss=0.11624838411808014
# Epoch 7, batch 1610: loss=0.14146901667118073
# Epoch 7, batch 1620: loss=0.16173096001148224
# Epoch 7, batch 1630: loss=0.12706133723258972
# Epoch 7, batch 1640: loss=0.13267548382282257
# Epoch 7, batch 1650: loss=0.1107092797756195
# Epoch 7, batch 1660: loss=0.14430087804794312
# Epoch 7, batch 1670: loss=0.13735628128051758
# Epoch 7, batch 1680: loss=0.14502710103988647
# Epoch 7, batch 1690: loss=0.11691693961620331
# Epoch 7, batch 1700: loss=0.14572617411613464
# Epoch 7, batch 1710: loss=0.13849885761737823
# Epoch 7, batch 1720: loss=0.11944552510976791
# Epoch 7, batch 1730: loss=0.10184784233570099
# Epoch 7, batch 1740: loss=0.1574598252773285
# Epoch 7, batch 1750: loss=0.12085820734500885
# Epoch 7, batch 1760: loss=0.12333159148693085
# Epoch 7, batch 1770: loss=0.14326834678649902
# Epoch 7, batch 1780: loss=0.11929035931825638
# Epoch 7, batch 1790: loss=0.13135333359241486
# Epoch 7, batch 1800: loss=0.14259251952171326
# Epoch 7, batch 1810: loss=0.11680762469768524
# Epoch 7, batch 1820: loss=0.12137453258037567
# Epoch 7, batch 1830: loss=0.12661682069301605
# Epoch 7, batch 1840: loss=0.13792143762111664
# Epoch 7, batch 1850: loss=0.14605459570884705
# Epoch 7, batch 1860: loss=0.13603095710277557
# Epoch 7, batch 1870: loss=0.13300678133964539
# Epoch 7, batch 1880: loss=0.14252035319805145
# Epoch 7, batch 1890: loss=0.1264810413122177
# Epoch 7, batch 1900: loss=0.15553580224514008
# Epoch 7, batch 1910: loss=0.1236129179596901
# Epoch 7, batch 1920: loss=0.1789502203464508
# Epoch 7, batch 1930: loss=0.15306662023067474
# Epoch 7, batch 1940: loss=0.13174155354499817
# Epoch 7, batch 1950: loss=0.131852924823761
# Epoch 7, batch 1960: loss=0.16403330862522125
# Epoch 7, batch 1970: loss=0.1375572234392166
# Epoch 7, batch 1980: loss=0.13712278008460999
# Epoch 7, batch 1990: loss=0.1336764395236969
#
#
#
# HOrgblySp
# NIO''e' A 'b'
#
# ''A''VI OP in cat KI brat pidhautlyT pow oemean grswrsesedond wornif thillceke wous orsud stgh omad uennow Roveon:
# We?
# VIst, th lutisit so thonk syove tilleee
# Arceoupd TI keutthoon ifuth wn'wonkeshs,
# Von brth domiaty, shathee no hain, serle meofrd ve, covelll sac? bemsg,
# In tw! nopo whet merrsews condle
# I CKId mou?
# Bixercoy INCOIF s,
# Rot thllorn 's oppdoundl
# IEThand IT
# jodser wh Yomcher whensal sh cousth Ke my Ilditond ler wint.
#
# BIOKCOL:
# LAlO:
# GSisd ine lor mel,
# Whe:
# Th Moth tepangafdr Ibesn, fo sacke arternethom move,
# Wheret sw?
# Whore ligo conkeiogo seaken ris somigerass:
#
# Fhellond moih ome.
# LECHAUCHE IOUI tot sed
#
# .
# TIORLUCG RUGRERL:
# LUGRR:
# SS:
# GR:
#
# Ronthat yo vee, thupreInt tet. he bw
# Mom
# BISAUMUKS:
# TISCy IM:
# So kuvispl Iutlor wike urust wont, soferd crothaf adomalermy hovad:
# Wrer thas toutgo besWot.
# WIbindoells fatl, shotrra hedorit
# Wartthe: ows of hadarcey ceit tomisge theven se, tlenecof
# Ay sveest wifavat tl fourccodsk Ifownorest.
# Amy westhU: wing wen:
#
#
# Epoch 7, batch 2000: loss=0.13538315892219543
# Epoch 7, batch 2010: loss=0.11724940687417984
# Epoch 7, batch 2020: loss=0.11344064772129059
# Epoch 7, batch 2030: loss=0.13616321980953217
# Epoch 7, batch 2040: loss=0.10421870648860931
# Epoch 7, batch 2050: loss=0.13377645611763
# Epoch 7, batch 2060: loss=0.11459561437368393
# Epoch 7, batch 2070: loss=0.12963151931762695
# Epoch 7, batch 2080: loss=0.13944804668426514
# Epoch 7, batch 2090: loss=0.11670836806297302
# Epoch 7, batch 2100: loss=0.1300084888935089
# Epoch 7, batch 2110: loss=0.13362130522727966
# Epoch 7, batch 2120: loss=0.1614476591348648
# Epoch 7, batch 2130: loss=0.15038177371025085
# Epoch 7, batch 2140: loss=0.12040971219539642
# Epoch 7, batch 2150: loss=0.12076736986637115
# Epoch 7, batch 2160: loss=0.11186113953590393
# Epoch 7, batch 2170: loss=0.1604015827178955
#
#
# QROcPebyvemby
# '
# '--b'------------lo-----ri---r' --d cd o-ld mo-dooicrod:
#
# oreyerokertnc yo wir bde on ar'den'o noer yot ary he faeeniterou I hennte tour coist us hatre, wit, ictrchenesu sie ains, oary wish,
# Any isound,e arngke nooum hach founit eag  przfpoong:
# Oat athimang youno tead inge wan, mio wouthos harous iturd,hasw torn woby saks ouer?
#
# KIOLOSE IOLO bu hou Than ind bermoee s,
# 'sse?on miy erhair has ghir' yo'y wiry montche
# ED menoure:
#
# Iat leed hod f te veezuflon? ony be bow wistx he.
# Lof do ou
# Huneetou po-pr pot apr aromyoeris.
# Sik ig hoire ro mirf noole Ia tol mivers,
# Hinahont; od set kenimaery opbe? the'de or
#
# Are!
# NoMaseewhic.
# Ei ne. at ariolfore ig hongheedy ye apoy nbeens an diutarcenou mouran, fout eorey an tont mode f withererame?
#
# Tove wand woid hy wou's topbe hace caim fo'lean,
# :
# yare beo gond ouer ainich rindinu icupo ard, lousghosueretheps yoprce; etharoveet curore arnve wK:
# Naig chof sear;
# I fou!
# Jof pdar ionde wenwenang yowir d aodr heriny,
# Farlen orso thaiprew:-e,
#
# Epoch 8, batch 0: loss=0.12285052984952927
# Epoch 8, batch 10: loss=0.1358935832977295
# Epoch 8, batch 20: loss=0.12021235376596451
# Epoch 8, batch 30: loss=0.12241052091121674
# Epoch 8, batch 40: loss=0.12215270847082138
# Epoch 8, batch 50: loss=0.13565176725387573
# Epoch 8, batch 60: loss=0.11865495145320892
# Epoch 8, batch 70: loss=0.11999369412660599
# Epoch 8, batch 80: loss=0.13515108823776245
# Epoch 8, batch 90: loss=0.1473071128129959
# Epoch 8, batch 100: loss=0.14220879971981049
# Epoch 8, batch 110: loss=0.11283546686172485
# Epoch 8, batch 120: loss=0.09527864307165146
# Epoch 8, batch 130: loss=0.14014126360416412
# Epoch 8, batch 140: loss=0.11959168314933777
# Epoch 8, batch 150: loss=0.12803012132644653
# Epoch 8, batch 160: loss=0.09636831283569336
# Epoch 8, batch 170: loss=0.12421651184558868
# Epoch 8, batch 180: loss=0.1363658607006073
# Epoch 8, batch 190: loss=0.13567504286766052
# Epoch 8, batch 200: loss=0.1366971731185913
# Epoch 8, batch 210: loss=0.12834292650222778
# Epoch 8, batch 220: loss=0.11945639550685883
# Epoch 8, batch 230: loss=0.12427426874637604
# Epoch 8, batch 240: loss=0.1347178816795349
# Epoch 8, batch 250: loss=0.13765741884708405
# Epoch 8, batch 260: loss=0.12922444939613342
# Epoch 8, batch 270: loss=0.14193613827228546
# Epoch 8, batch 280: loss=0.10222572833299637
# Epoch 8, batch 290: loss=0.1537613719701767
# Epoch 8, batch 300: loss=0.12947256863117218
# Epoch 8, batch 310: loss=0.13633573055267334
# Epoch 8, batch 320: loss=0.11234613507986069
# Epoch 8, batch 330: loss=0.1518443524837494
# Epoch 8, batch 340: loss=0.10234242677688599
# Epoch 8, batch 350: loss=0.10377094894647598
# Epoch 8, batch 360: loss=0.12647122144699097
# Epoch 8, batch 370: loss=0.11463730037212372
# Epoch 8, batch 380: loss=0.12501338124275208
# Epoch 8, batch 390: loss=0.1305675357580185
# Epoch 8, batch 400: loss=0.14009633660316467
# Epoch 8, batch 410: loss=0.1424187868833542
# Epoch 8, batch 420: loss=0.1871044635772705
# Epoch 8, batch 430: loss=0.13431455194950104
# Epoch 8, batch 440: loss=0.13478413224220276
# Epoch 8, batch 450: loss=0.12635864317417145
# Epoch 8, batch 460: loss=0.12707878649234772
# Epoch 8, batch 470: loss=0.11995864659547806
# Epoch 8, batch 480: loss=0.11413680016994476
# Epoch 8, batch 490: loss=0.10662205517292023
#
#
# HENnk'evep-d L E'
# ''n'''''''''''eri''n'''''''''''''''''en'''''','''''F'''''''''en'' 'e'''''t'''':''''''''''L''''''''''''r'''''''''''''' ''''';''e'':'''''e'' 'e''e''''
# ''t''L''''''' 'e''e'''''''''e'':'''e'''e'''''''y'e''''''e'''e''',''e''ee'e'e
# ''e'ee''ei'e''eee'eeeed.
# e In'we: de.'en?.': net thelle ye! thue:
# on'l, the mweseou'd.'d mcrethm foor. d,
# Gsoun turatrngen,
# At thas treu, foucarht thenghI the wells, kned.
#
# G urt uedyo Orle?out?
# W!; orollinget he ino. mewe ich owan thy e;
# Fe'ss yo 've:
# Areseld, cood Ied due sillom mohis th miavere ors lyou
# Bore the hy, eat re woull thit m herques bet hicr thag melfr,
# Ir pet sou:
# At oy te mit ove isu sueus.'s the ou qut Coreaf laslrieg:
# P:
# Guren:
# Iu cay thetGu ngre ay hu hy lud far: poce's:'dore ner at thi nd. want,
#
# I thay chug che unore.
# RARIFBERTheas IX' lunteramt,; tpry hiof seser Iu her, o tou:
# g ay thore mehere torl pellug Ire tive teel se. hish it eruly t.
#
# VOLA bigher yey, ure arely ber fout wory Gofmy dame, tane grove dof tine se thounget
#
# Epoch 8, batch 500: loss=0.09839465469121933
# Epoch 8, batch 510: loss=0.15299704670906067
# Epoch 8, batch 520: loss=0.1425338238477707
# Epoch 8, batch 530: loss=0.10729535669088364
# Epoch 8, batch 540: loss=0.1176227480173111
# Epoch 8, batch 550: loss=0.1125807911157608
# Epoch 8, batch 560: loss=0.12224818021059036
# Epoch 8, batch 570: loss=0.09805867075920105
# Epoch 8, batch 580: loss=0.1324550211429596
# Epoch 8, batch 590: loss=0.13131439685821533
# Epoch 8, batch 600: loss=0.10385966300964355
# Epoch 8, batch 610: loss=0.09615767747163773
# Epoch 8, batch 620: loss=0.10210874676704407
# Epoch 8, batch 630: loss=0.14302527904510498
# Epoch 8, batch 640: loss=0.10348209738731384
# Epoch 8, batch 650: loss=0.13158956170082092
# Epoch 8, batch 660: loss=0.13347750902175903
# Epoch 8, batch 670: loss=0.14677849411964417
# Epoch 8, batch 680: loss=0.1236940249800682
# Epoch 8, batch 690: loss=0.12241445481777191
# Epoch 8, batch 700: loss=0.10914449393749237
# Epoch 8, batch 710: loss=0.11880028992891312
# Epoch 8, batch 720: loss=0.12724953889846802
# Epoch 8, batch 730: loss=0.12382680177688599
# Epoch 8, batch 740: loss=0.10990474373102188
# Epoch 8, batch 750: loss=0.14017488062381744
# Epoch 8, batch 760: loss=0.12481080740690231
# Epoch 8, batch 770: loss=0.14033880829811096
# Epoch 8, batch 780: loss=0.1473109871149063
# Epoch 8, batch 790: loss=0.11391216516494751
# Epoch 8, batch 800: loss=0.1445719301700592
# Epoch 8, batch 810: loss=0.11992451548576355
# Epoch 8, batch 820: loss=0.13190114498138428
# Epoch 8, batch 830: loss=0.1194785088300705
# Epoch 8, batch 840: loss=0.11385869979858398
# Epoch 8, batch 850: loss=0.1548682153224945
# Epoch 8, batch 860: loss=0.1260164976119995
# Epoch 8, batch 870: loss=0.1522517204284668
# Epoch 8, batch 880: loss=0.12689493596553802
# Epoch 8, batch 890: loss=0.13283929228782654
# Epoch 8, batch 900: loss=0.11186593770980835
# Epoch 8, batch 910: loss=0.09617090970277786
# Epoch 8, batch 920: loss=0.11018532514572144
# Epoch 8, batch 930: loss=0.1120627373456955
# Epoch 8, batch 940: loss=0.11576409637928009
# Epoch 8, batch 950: loss=0.11924803256988525
# Epoch 8, batch 960: loss=0.10289380699396133
# Epoch 8, batch 970: loss=0.11656089127063751
# Epoch 8, batch 980: loss=0.1436913162469864
# Epoch 8, batch 990: loss=0.12446557730436325
#
#
# KEOStyvin'Gl'
#
# HA A'A'A'r''''';
# An'HAben'd IS'ndes'bfe dle wownre the spigh fonomy. s beatKins perg arens, nYoowKe ce, Dinller Thy aket nlugs eadis sh bt. hid
# AUlacurevegr:
# AWharheve shy sar ghathy youllis h as out ngt suner.
#
# CIOSTRUNT:
# Sy atulit st rou wh ce--lir ho nud.
# HESbugholy.
#
# Ber wangu-HEROrody r.
#
# Way noit, ldrin thollkl, gont wit hryd, had, st wad ut pant bo se prvereetholl he hesu
# Andt Mesthe,
# Andw:
# Anewite cou har, bleh, isevit lais tor mofli vane acerves ds yliar nest.
# DY ace whux aipan ay pe hunten yo pfoullpil lousud es henthes ou Ceey sucupt herounyes IOd any couY mael?
# Asand, shild:
# An ser, sodg thedey yo'delye pou pe ge!
# gn;
# ARI Enophay athew ty, por tharand wof le ashes wh tound; thansldus Asthe, lasth Ire, Houl on ldit
# Eusgelver tors, gh ke han, boff
# A:
# G rou:
# Inon toud theedt shie te sen te.
# TRIThind noun titons man wlou wo wians I ghugl hetw tend sot ow, ceyssat Iin sews wawe; that me: thet mareomand th,-of he b;ee brou ved that with no wist yeereslo coug ou lro
#
# Epoch 8, batch 1000: loss=0.11543715000152588
# Epoch 8, batch 1010: loss=0.11656050384044647
# Epoch 8, batch 1020: loss=0.14728650450706482
# Epoch 8, batch 1030: loss=0.1142406016588211
# Epoch 8, batch 1040: loss=0.12361784279346466
# Epoch 8, batch 1050: loss=0.10648678243160248
# Epoch 8, batch 1060: loss=0.10985715687274933
# Epoch 8, batch 1070: loss=0.12305525690317154
# Epoch 8, batch 1080: loss=0.1530429571866989
# Epoch 8, batch 1090: loss=0.1368762105703354
# Epoch 8, batch 1100: loss=0.10199198126792908
# Epoch 8, batch 1110: loss=0.14513561129570007
# Epoch 8, batch 1120: loss=0.1004941314458847
# Epoch 8, batch 1130: loss=0.14935751259326935
# Epoch 8, batch 1140: loss=0.17803849279880524
# Epoch 8, batch 1150: loss=0.12127562612295151
# Epoch 8, batch 1160: loss=0.12322551757097244
# Epoch 8, batch 1170: loss=0.13873828947544098
# Epoch 8, batch 1180: loss=0.11658277362585068
# Epoch 8, batch 1190: loss=0.1223902776837349
# Epoch 8, batch 1200: loss=0.12264729291200638
# Epoch 8, batch 1210: loss=0.145694300532341
# Epoch 8, batch 1220: loss=0.1169862151145935
# Epoch 8, batch 1230: loss=0.1095486506819725
# Epoch 8, batch 1240: loss=0.13260088860988617
# Epoch 8, batch 1250: loss=0.1223737820982933
# Epoch 8, batch 1260: loss=0.126832515001297
# Epoch 8, batch 1270: loss=0.11589467525482178
# Epoch 8, batch 1280: loss=0.15834182500839233
# Epoch 8, batch 1290: loss=0.12172692269086838
# Epoch 8, batch 1300: loss=0.12033937871456146
# Epoch 8, batch 1310: loss=0.1310998946428299
# Epoch 8, batch 1320: loss=0.12606486678123474
# Epoch 8, batch 1330: loss=0.1498478204011917
# Epoch 8, batch 1340: loss=0.10904543101787567
# Epoch 8, batch 1350: loss=0.1283869445323944
# Epoch 8, batch 1360: loss=0.13295242190361023
# Epoch 8, batch 1370: loss=0.15417590737342834
# Epoch 8, batch 1380: loss=0.12493215501308441
# Epoch 8, batch 1390: loss=0.14226429164409637
# Epoch 8, batch 1400: loss=0.13017597794532776
# Epoch 8, batch 1410: loss=0.10754681378602982
# Epoch 8, batch 1420: loss=0.13381284475326538
# Epoch 8, batch 1430: loss=0.13062037527561188
# Epoch 8, batch 1440: loss=0.1360231339931488
# Epoch 8, batch 1450: loss=0.1230429857969284
# Epoch 8, batch 1460: loss=0.10835455358028412
# Epoch 8, batch 1470: loss=0.09174737334251404
# Epoch 8, batch 1480: loss=0.10760103911161423
# Epoch 8, batch 1490: loss=0.10673026740550995
#
#
# KEtquMy:
# Hey; ENb' HALn HAA''''dold niw, sarandisard thangs iesthasty, go heldat hand seme tof henday se Tular thoby,
# Mes ing hortcesris sw thovertob'rmaiatt worsthe sitily ficn'd net swin tholy Gyoun-t.
#
# HATHEOLERCAEENUA:
# Are I d, seno, wordey.
# G won HE huktora tast btoret berth,
# Thang briss keng Edrigh sheld reyse thar deals i.
# Gondent pesillge:
# Thite thaly deshimer bhe do slang thindor ches pohod th contparsd hele yod the oris, theeng scot ss tordebngtgser d
# ITho beroldy hat s rodchend stond gourcendce! ten ise ag nthax? toll ousst ghecurornle re? wity jons fors ye
# Dusy lo Eoures tarlt ene ai omst ndy veof ourg srt ainthay dot sinibrenary head, merars hit arn be-der dotur: poidt yog itindtine rredeis, athe; collon Mare, stll ben, tan bret aflloth Cols llla'suston spagh mbto heu this eraclers dat cous,
# NTha tath ol ntlish:
# A wnerst weliers
# wa methe ry, tof Cowrecd gre.
# EROdeistogne ces cinorcugeds inces hicn wost ue spilllise heng.
# Thine thng merdestrce gran hamy the uat nou btors es
#
# Epoch 8, batch 1500: loss=0.1398087441921234
# Epoch 8, batch 1510: loss=0.13128793239593506
# Epoch 8, batch 1520: loss=0.12521059811115265
# Epoch 8, batch 1530: loss=0.11719200760126114
# Epoch 8, batch 1540: loss=0.11141149699687958
# Epoch 8, batch 1550: loss=0.13409492373466492
# Epoch 8, batch 1560: loss=0.11528927832841873
# Epoch 8, batch 1570: loss=0.12333285808563232
# Epoch 8, batch 1580: loss=0.12480460107326508
# Epoch 8, batch 1590: loss=0.12858957052230835
# Epoch 8, batch 1600: loss=0.13618236780166626
# Epoch 8, batch 1610: loss=0.11734016239643097
# Epoch 8, batch 1620: loss=0.15651553869247437
# Epoch 8, batch 1630: loss=0.09594470262527466
# Epoch 8, batch 1640: loss=0.1067165732383728
# Epoch 8, batch 1650: loss=0.11223019659519196
# Epoch 8, batch 1660: loss=0.12431668490171432
# Epoch 8, batch 1670: loss=0.1364661455154419
# Epoch 8, batch 1680: loss=0.14816948771476746
# Epoch 8, batch 1690: loss=0.14741595089435577
# Epoch 8, batch 1700: loss=0.10802658647298813
# Epoch 8, batch 1710: loss=0.13435222208499908
# Epoch 8, batch 1720: loss=0.1523594856262207
# Epoch 8, batch 1730: loss=0.12215867638587952
# Epoch 8, batch 1740: loss=0.10214760899543762
# Epoch 8, batch 1750: loss=0.12875032424926758
# Epoch 8, batch 1760: loss=0.09574779123067856
# Epoch 8, batch 1770: loss=0.1945304125547409
# Epoch 8, batch 1780: loss=0.13746105134487152
# Epoch 8, batch 1790: loss=0.1208784282207489
# Epoch 8, batch 1800: loss=0.1535218209028244
# Epoch 8, batch 1810: loss=0.14035817980766296
# Epoch 8, batch 1820: loss=0.10245142877101898
# Epoch 8, batch 1830: loss=0.12946060299873352
# Epoch 8, batch 1840: loss=0.10857366025447845
# Epoch 8, batch 1850: loss=0.11796197295188904
# Epoch 8, batch 1860: loss=0.10376638919115067
# Epoch 8, batch 1870: loss=0.10651096701622009
# Epoch 8, batch 1880: loss=0.1417744904756546
# Epoch 8, batch 1890: loss=0.11655596643686295
# Epoch 8, batch 1900: loss=0.09998887032270432
# Epoch 8, batch 1910: loss=0.10258540511131287
# Epoch 8, batch 1920: loss=0.12432730942964554
# Epoch 8, batch 1930: loss=0.11152544617652893
# Epoch 8, batch 1940: loss=0.13485072553157806
# Epoch 8, batch 1950: loss=0.0702126994729042
# Epoch 8, batch 1960: loss=0.12528270483016968
# Epoch 8, batch 1970: loss=0.12078025937080383
# Epoch 8, batch 1980: loss=0.10302991420030594
# Epoch 8, batch 1990: loss=0.1296388953924179
#
#
# HEntyny;
# A p--I'e''''
# '''''''''''ee''ein'e'''''eeee''ee'e,
# 'e, ee,
# ADadeeereeeave llen, aldren that adebee gend und rsselyue maol Roc'kreas;
#
# ARIO:
# ARA Mearzhe nof ausas sd I mqulmolled cord ors hache fe,sar, dromlzf thee ay id foinde?
# LD mer yof athe thilg
# Yos? us POL
# Cio cof wing foure,
# RD eod cinm'se thaver:
# That ireny wethin:
# Angrow to the ang butend abr, wulen ond ipeadlsbsst e
# The sht df athetheee, et of heats auce, po hefoy?
# Th'e thenocareesp nos deres im theenee seha-eet toon I sescor hendod drs the.
# Be bakSe ish bo?
# A MO:
# Mhgu ler hey beaveer baghadeecof
# There mealeeead lf hen orea dals toy duny
# Al,
# A:
# Ty Trimeid st icham pat wneucelo wech;
# oover lis the awemot;
# Annd hine; neary Ug
# I ney the I at thet seeth thad buedod er
# RTupy eany ta maskerca hies hih swacax heras hame.
# Fend:
# KENWIED sandes sar die sig; ppeghathendofet -heth ift no dkestoud then me ghet noeler;
# Antn; ns the, sea ag mawo dgres apuorond thiers' ad dar ch sevesaralleso irt
# Haki-E dere matve foud ail!
# este thar
#
# Epoch 8, batch 2000: loss=0.11595061421394348
# Epoch 8, batch 2010: loss=0.1155300959944725
# Epoch 8, batch 2020: loss=0.1143171489238739
# Epoch 8, batch 2030: loss=0.14873623847961426
# Epoch 8, batch 2040: loss=0.09914281219244003
# Epoch 8, batch 2050: loss=0.13976886868476868
# Epoch 8, batch 2060: loss=0.13246990740299225
# Epoch 8, batch 2070: loss=0.12948952615261078
# Epoch 8, batch 2080: loss=0.11617700010538101
# Epoch 8, batch 2090: loss=0.134199321269989
# Epoch 8, batch 2100: loss=0.11724212765693665
# Epoch 8, batch 2110: loss=0.12180346995592117
# Epoch 8, batch 2120: loss=0.11909810453653336
# Epoch 8, batch 2130: loss=0.10677235573530197
# Epoch 8, batch 2140: loss=0.14530327916145325
# Epoch 8, batch 2150: loss=0.13204622268676758
# Epoch 8, batch 2160: loss=0.1051386147737503
# Epoch 8, batch 2170: loss=0.10461936146020889
#
#
# HEd'b? Lor byay; '
# 'bb'''''''''d
# 'Le; h'en't binuthee Saus. bath at ar pigher slet tefh xe; owit.
#
#
# ARORVORI:
# F yourthat preu tout fopl, bur besoue; heall.
#
# POROLoy his pufhet bald dexto
# fot fatl oullische seurin en thuk'd skoak mout' sad sine!
# Lfads ownict,
# Tfaas tegavin mat,
# Wand ant wirfiyat
#  mond yor atheu beno bu 'dve; pane qur:
# Teanduthestre l twe ahtouk no tut horimeru kanghty wwil,
# KI we wis buand bee thief the heke fo fou VI kufwrit pist be dinthe weilv ghon? nofto,
#
# f thonstn sounto st-usneseto insou lot sinvee?
#
# sou INCK:
# Sertu win: yanoait he te y illett;
# I cloutl an;
# Youk, whe your yauly wsaint, vithe, befie?
#
# at whwe whan has fond lad he mariny
#
# Wape
# Bes ISAn wies shat, and of hath.
#
# KID wank rknoue go buawink, wite ifll hoffehull ing.
# The
# Qih beG finothoin hy houg withtu.
#
# HA GI puord buswik?
# G ifrary for aly fofour brde theskn a-Pe;
# Secanly:
# -out, tey wo buiskr bown,n you thind an hy bithe buravim,
# I budan yarm, yoru a, ay Jnof ho that yo te Jupomontof cou,
# poboD-
# Pw ya
#
# Epoch 9, batch 0: loss=0.1290448009967804
# Epoch 9, batch 10: loss=0.10212293267250061
# Epoch 9, batch 20: loss=0.08604303002357483
# Epoch 9, batch 30: loss=0.09503377974033356
# Epoch 9, batch 40: loss=0.1276424676179886
# Epoch 9, batch 50: loss=0.0876956433057785
# Epoch 9, batch 60: loss=0.15415413677692413
# Epoch 9, batch 70: loss=0.08024481683969498
# Epoch 9, batch 80: loss=0.1135430634021759
# Epoch 9, batch 90: loss=0.11278560012578964
# Epoch 9, batch 100: loss=0.13268539309501648
# Epoch 9, batch 110: loss=0.0982377827167511
# Epoch 9, batch 120: loss=0.12602725625038147
# Epoch 9, batch 130: loss=0.12430380284786224
# Epoch 9, batch 140: loss=0.12569455802440643
# Epoch 9, batch 150: loss=0.0968538299202919
# Epoch 9, batch 160: loss=0.13656562566757202
# Epoch 9, batch 170: loss=0.09640432149171829
# Epoch 9, batch 180: loss=0.12405382096767426
# Epoch 9, batch 190: loss=0.13232707977294922
# Epoch 9, batch 200: loss=0.15597084164619446
# Epoch 9, batch 210: loss=0.12992608547210693
# Epoch 9, batch 220: loss=0.10678106546401978
# Epoch 9, batch 230: loss=0.09888547658920288
# Epoch 9, batch 240: loss=0.11473462730646133
# Epoch 9, batch 250: loss=0.16958287358283997
# Epoch 9, batch 260: loss=0.1183641329407692
# Epoch 9, batch 270: loss=0.11269286274909973
# Epoch 9, batch 280: loss=0.07988634705543518
# Epoch 9, batch 290: loss=0.09723794460296631
# Epoch 9, batch 300: loss=0.11921700090169907
# Epoch 9, batch 310: loss=0.08531121909618378
# Epoch 9, batch 320: loss=0.09942135214805603
# Epoch 9, batch 330: loss=0.12678006291389465
# Epoch 9, batch 340: loss=0.09729181230068207
# Epoch 9, batch 350: loss=0.11671143770217896
# Epoch 9, batch 360: loss=0.10161825269460678
# Epoch 9, batch 370: loss=0.10853969305753708
# Epoch 9, batch 380: loss=0.0926915854215622
# Epoch 9, batch 390: loss=0.1303717941045761
# Epoch 9, batch 400: loss=0.099555604159832
# Epoch 9, batch 410: loss=0.09650759398937225
# Epoch 9, batch 420: loss=0.1298518180847168
# Epoch 9, batch 430: loss=0.12130460888147354
# Epoch 9, batch 440: loss=0.12341255694627762
# Epoch 9, batch 450: loss=0.11469313502311707
# Epoch 9, batch 460: loss=0.1441764384508133
# Epoch 9, batch 470: loss=0.1511421501636505
# Epoch 9, batch 480: loss=0.10036429762840271
# Epoch 9, batch 490: loss=0.10227841883897781
#
#
# HENTaLMy;
# A' by
# '' b'
# ''
# ''''''ben' bly de th'eepeerd'odpal petpe?
# Apde owpit wpe sice he dsepd prex pasetl!
# The lfoull!
# D-'d he PDnuldest
# MA:
# ARoous ilom I's set poang.
# CAD:
# Serge ciny'e ctorss,
# LA mabr homesdcat st adrod th sopet Cle po thxea cos novet bhechaty sey, tousty lele wanm bre 'st,
# Acllod shimerdem'd mat ghaves theulem'd by! me'lkis himind the lent ict theve:
# Ind.
# RWepisc.
# Whescel.
# Whe tillel
#
# Sea:
# Tyrisdy an.
# SILA
# IFtcuet IA:
# Belan ind tlde pa n? thin Canmeba?
# ARECI
# AD ipes,
# Las has?
# pt st to peat prat gdt catse sotind tr meanmes shingricoond illle;
#
# LLEORES:
# Ade; al darou serdis nt izrecinnm theg touspdky anssesdckne,
# I th hide pest Cod wheby.
# Se Corestosespayol;
#
# IE, Sinlell Sitom beangatid mre-sitcy
# Hand owned ud ant angit borcam tad anghengelextche!
#
# Eu'ld peousty leh hesdim, sdibrD qustutitge ghers bacbe omeurelthes tiscksuge!
# L dildust skemer tstmee calcs beesofpe se ane
# Est-Scithob,
# Sbengeomy ws hapdenis, my, ichershe thit sengnthes yes,
# Thythand lede molde? petPSge
#
# Epoch 9, batch 500: loss=0.10324195772409439
# Epoch 9, batch 510: loss=0.16536583006381989
# Epoch 9, batch 520: loss=0.10911385715007782
# Epoch 9, batch 530: loss=0.11498098820447922
# Epoch 9, batch 540: loss=0.12259158492088318
# Epoch 9, batch 550: loss=0.11841320246458054
# Epoch 9, batch 560: loss=0.14314819872379303
# Epoch 9, batch 570: loss=0.12255412340164185
# Epoch 9, batch 580: loss=0.09728839993476868
# Epoch 9, batch 590: loss=0.12935054302215576
# Epoch 9, batch 600: loss=0.12634886801242828
# Epoch 9, batch 610: loss=0.12067040055990219
# Epoch 9, batch 620: loss=0.1054641455411911
# Epoch 9, batch 630: loss=0.1162041500210762
# Epoch 9, batch 640: loss=0.11859539151191711
# Epoch 9, batch 650: loss=0.1154869943857193
# Epoch 9, batch 660: loss=0.09314269572496414
# Epoch 9, batch 670: loss=0.1237344741821289
# Epoch 9, batch 680: loss=0.09758704900741577
# Epoch 9, batch 690: loss=0.08157475292682648
# Epoch 9, batch 700: loss=0.10496484488248825
# Epoch 9, batch 710: loss=0.14166365563869476
# Epoch 9, batch 720: loss=0.1169532760977745
# Epoch 9, batch 730: loss=0.1316116601228714
# Epoch 9, batch 740: loss=0.10893567651510239
# Epoch 9, batch 750: loss=0.13877563178539276
# Epoch 9, batch 760: loss=0.08470338582992554
# Epoch 9, batch 770: loss=0.10052920132875443
# Epoch 9, batch 780: loss=0.08412754535675049
# Epoch 9, batch 790: loss=0.11030807346105576
# Epoch 9, batch 800: loss=0.126542329788208
# Epoch 9, batch 810: loss=0.13262543082237244
# Epoch 9, batch 820: loss=0.11794129014015198
# Epoch 9, batch 830: loss=0.11626586318016052
# Epoch 9, batch 840: loss=0.09913213551044464
# Epoch 9, batch 850: loss=0.11045582592487335
# Epoch 9, batch 860: loss=0.10727479308843613
# Epoch 9, batch 870: loss=0.12337278574705124
# Epoch 9, batch 880: loss=0.11200708895921707
# Epoch 9, batch 890: loss=0.09266917407512665
# Epoch 9, batch 900: loss=0.13509799540042877
# Epoch 9, batch 910: loss=0.1469893455505371
# Epoch 9, batch 920: loss=0.1533755362033844
# Epoch 9, batch 930: loss=0.11596164107322693
# Epoch 9, batch 940: loss=0.12238709628582001
# Epoch 9, batch 950: loss=0.12213881313800812
# Epoch 9, batch 960: loss=0.09854216128587723
# Epoch 9, batch 970: loss=0.1400325745344162
# Epoch 9, batch 980: loss=0.09893722832202911
# Epoch 9, batch 990: loss=0.1217297911643982
#
#
# KEtveczy;
#
# NR My'NR LRar;
#
# 'A''d,
# ir.:
# AUCQLay ue that.
#
# P:, chare im falll hig ho fgoov
# I
# NI HA s ofefte iera, hart skeam.
# Si Hery he;
# Hot nokis fpre pe hitanmf sene po m prneanenoe is,
# Ein:
# y il thigra fisthur mo coo to.
#
# AP: fothe riy thot tour le theat.
# Ay moD
# Biru t; fu tharinlis, wre wint, werw,he! Be dorthen, keseal rt wely, torthin se,vit athe lers,
#
# Fly wad, then oug, papu tey ibalot mist yofe
#
# Bisk tkerg athiy bse citedkinthl hof iree ate har ar th sutevethet hadse for trat swerylors rirt.
#
# GOD:
# Ard, fall, ang haveief ly Im
# I wikl my, re hy kan, duy. raphay for it.
# Pey:
# MI touners's therea tout rthmy aby helly.
#
# AUMENur NI allour sen, hon gha fe lall pets, war theserean Co keanw hareer alled dierwyer.
# Pak.
#
# A TRUICE dell the.
#
# PUCO:
# VI Errinill terug facoup o th:
#
# ound woy fond highuse? thi's yo mod rlle meen illlet,
# Aovar tl tireeat of thalen ts ouplett,
# Thourams te ompreld ebrovreceh la triar: ay.
# Po iks, -yard if lo kilknout sreak min els the ark
# Fass molria frignad dra?
# T
#
# Epoch 9, batch 1000: loss=0.1271207332611084
# Epoch 9, batch 1010: loss=0.09764795005321503
# Epoch 9, batch 1020: loss=0.1128043457865715
# Epoch 9, batch 1030: loss=0.09573465585708618
# Epoch 9, batch 1040: loss=0.09750191122293472
# Epoch 9, batch 1050: loss=0.11622056365013123
# Epoch 9, batch 1060: loss=0.11760950088500977
# Epoch 9, batch 1070: loss=0.12356152385473251
# Epoch 9, batch 1080: loss=0.08707505464553833
# Epoch 9, batch 1090: loss=0.12459266185760498
# Epoch 9, batch 1100: loss=0.11942003667354584
# Epoch 9, batch 1110: loss=0.11494451761245728
# Epoch 9, batch 1120: loss=0.10923857241868973
# Epoch 9, batch 1130: loss=0.10610844194889069
# Epoch 9, batch 1140: loss=0.10749562084674835
# Epoch 9, batch 1150: loss=0.10941405594348907
# Epoch 9, batch 1160: loss=0.10020244121551514
# Epoch 9, batch 1170: loss=0.11708250641822815
# Epoch 9, batch 1180: loss=0.11222988367080688
# Epoch 9, batch 1190: loss=0.11573980748653412
# Epoch 9, batch 1200: loss=0.09631969034671783
# Epoch 9, batch 1210: loss=0.09618385136127472
# Epoch 9, batch 1220: loss=0.11974290758371353
# Epoch 9, batch 1230: loss=0.11472240835428238
# Epoch 9, batch 1240: loss=0.13694463670253754
# Epoch 9, batch 1250: loss=0.10556906461715698
# Epoch 9, batch 1260: loss=0.11643777787685394
# Epoch 9, batch 1270: loss=0.12907052040100098
# Epoch 9, batch 1280: loss=0.09670398384332657
# Epoch 9, batch 1290: loss=0.11581345647573471
# Epoch 9, batch 1300: loss=0.11439572274684906
# Epoch 9, batch 1310: loss=0.10956314951181412
# Epoch 9, batch 1320: loss=0.11318688094615936
# Epoch 9, batch 1330: loss=0.13524338603019714
# Epoch 9, batch 1340: loss=0.11842906475067139
# Epoch 9, batch 1350: loss=0.10819419473409653
# Epoch 9, batch 1360: loss=0.10897229611873627
# Epoch 9, batch 1370: loss=0.10923424363136292
# Epoch 9, batch 1380: loss=0.11622609198093414
# Epoch 9, batch 1390: loss=0.09411075711250305
# Epoch 9, batch 1400: loss=0.10743719339370728
# Epoch 9, batch 1410: loss=0.10341101884841919
# Epoch 9, batch 1420: loss=0.11964821070432663
# Epoch 9, batch 1430: loss=0.10572981089353561
# Epoch 9, batch 1440: loss=0.1372103989124298
# Epoch 9, batch 1450: loss=0.1096114069223404
# Epoch 9, batch 1460: loss=0.1388266682624817
# Epoch 9, batch 1470: loss=0.12133146822452545
# Epoch 9, batch 1480: loss=0.09968532621860504
# Epoch 9, batch 1490: loss=0.09374134987592697
#
#
# HEnty;
# Nb! I' E'H'
# ''
# A H''''''one ho n'e.
# 'd cofad
#
# Wa;
# Put in an abirt omy, dno his. akist ye an:
# At hind heen of nos bok han thin than btof tod tant yake dr,
#
# Pingly ty thar minms, me, henkald pr do's, wi potw pipnrofpl,
# eand, the kindpe se aver genn:
# I pon, an:
# Soon pons lofut ar lare it t it ha oof she as
# H'd thof sithan, si ran lor cant iut mancth at wo santh on man:
#
# Anak I phar spom sth owner ta hend he pil tove hove kn maus, ig, ange
# L:
# My no hanisle sk th Mhe s then as ha aVand, Ar
# Whas, say lath ome in Ues lan thin; oon, mur drate h'e to erds ou thoun ile ds arn rn!
#
# Thaj th:
# Manhe ty neat ravee mor!
#
# Br'sthe Bea ben aidr: le! inrund?
# Hi k RI ho ber Har lyo man gf than, teresh,
# Avera, he arerk su ar wo brd! pave witl?
#
# Wit ro bor:
# pis plam arme tou lincw or heg face:
#
# Mau
# pan winar the atr mord, on ar wanoPlun tor se sen stot,
# Bs, hkirdor hee pat ptini br popo n
# Anist pof it, ol, breko phe sis long?
# The Hlis,
# Fl nid mat nng, he:
#
# Fo ingng wo t ceruind fq lliar se heminwur:
# F
#
# Epoch 9, batch 1500: loss=0.1249161809682846
# Epoch 9, batch 1510: loss=0.10628213733434677
# Epoch 9, batch 1520: loss=0.1139831468462944
# Epoch 9, batch 1530: loss=0.11286427080631256
# Epoch 9, batch 1540: loss=0.11829368770122528
# Epoch 9, batch 1550: loss=0.12151563167572021
# Epoch 9, batch 1560: loss=0.10165078192949295
# Epoch 9, batch 1570: loss=0.11735914647579193
# Epoch 9, batch 1580: loss=0.11444857716560364
# Epoch 9, batch 1590: loss=0.10978837311267853
# Epoch 9, batch 1600: loss=0.09090486168861389
# Epoch 9, batch 1610: loss=0.11608284711837769
# Epoch 9, batch 1620: loss=0.10992630571126938
# Epoch 9, batch 1630: loss=0.09829876571893692
# Epoch 9, batch 1640: loss=0.1315998136997223
# Epoch 9, batch 1650: loss=0.11695509403944016
# Epoch 9, batch 1660: loss=0.10753358900547028
# Epoch 9, batch 1670: loss=0.12904849648475647
# Epoch 9, batch 1680: loss=0.16002866625785828
# Epoch 9, batch 1690: loss=0.11925964057445526
# Epoch 9, batch 1700: loss=0.10439581423997879
# Epoch 9, batch 1710: loss=0.1030159741640091
# Epoch 9, batch 1720: loss=0.09045561403036118
# Epoch 9, batch 1730: loss=0.11151602864265442
# Epoch 9, batch 1740: loss=0.09043539315462112
# Epoch 9, batch 1750: loss=0.11678289622068405
# Epoch 9, batch 1760: loss=0.09592101722955704
# Epoch 9, batch 1770: loss=0.09897272288799286
# Epoch 9, batch 1780: loss=0.11667154729366302
# Epoch 9, batch 1790: loss=0.10111381858587265
# Epoch 9, batch 1800: loss=0.11945757269859314
# Epoch 9, batch 1810: loss=0.1366901397705078
# Epoch 9, batch 1820: loss=0.11596134305000305
# Epoch 9, batch 1830: loss=0.1264505237340927
# Epoch 9, batch 1840: loss=0.10764622688293457
# Epoch 9, batch 1850: loss=0.10891658812761307
# Epoch 9, batch 1860: loss=0.1481175273656845
# Epoch 9, batch 1870: loss=0.11211880296468735
# Epoch 9, batch 1880: loss=0.13525688648223877
# Epoch 9, batch 1890: loss=0.1109960675239563
# Epoch 9, batch 1900: loss=0.08822719752788544
# Epoch 9, batch 1910: loss=0.11243468523025513
# Epoch 9, batch 1920: loss=0.11245530098676682
# Epoch 9, batch 1930: loss=0.10348901897668839
# Epoch 9, batch 1940: loss=0.09706856310367584
# Epoch 9, batch 1950: loss=0.10275957733392715
# Epoch 9, batch 1960: loss=0.1319914609193802
# Epoch 9, batch 1970: loss=0.1200503408908844
# Epoch 9, batch 1980: loss=0.0912148654460907
# Epoch 9, batch 1990: loss=0.1053309291601181
#
#
# HEd'Styne' M--
# '''r L '''''''''dF'elin'e'y h''''''e''e'en'e'''''e'''e'e ''''''e'ee''e'e'e'ee''eeeareee'!'''e'e:'e,'e''eAR' 'ieeo':
# Io':'' the od.
# L'd withemord wo JofJ'd:
# I'dd somivesptadand he avend boveraod hedi!
# O: y! dyowy
# Mtcue aif lich winivef aolmeil.
# wlith telerse dixetd blowert coutousce orn; inalancnroy cour, angerolle acky.
# RIO:
# Woly. Boon, hey de gnonusee.
# RIODI:
# GWhe:
# Rgne wond, cournotphe g Gothe'd; wakrd;'d igas the thendindyof as chaljoncengr ance cof wintest
# AR:
# ARoolindlt Itl wete setouprdth aked youtin encthes seene cewa ced.
# I CAnd Kighacw:
# Atou kiod medubetthet aumy my, atlenen? I sunow, u, wioly
# Whe taighseth pay wiglve cire
# Bnowon,ve t hay beny alll chen chexer wisheernt hedricel, anse Vo? pingetwes
# Wh boundasditrith,
# I blvofy hes muph bondoolle ty!
# Tilld oundit wenkes pit mot ome ho th oppse'd wh?Fas ty mee, ser anc'st:
# O orar stormyond an breint
# Tou Wangouresturek'thes hwacikedoe? beraay, d me' laveutht.
# Of, plug, imy  aveantulingam wy,d:
# Thengajed wheavins, hi
#
# Epoch 9, batch 2000: loss=0.10606909543275833
# Epoch 9, batch 2010: loss=0.11784764379262924
# Epoch 9, batch 2020: loss=0.1361750066280365
# Epoch 9, batch 2030: loss=0.1262328177690506
# Epoch 9, batch 2040: loss=0.1249183863401413
# Epoch 9, batch 2050: loss=0.12017729878425598
# Epoch 9, batch 2060: loss=0.09842479228973389
# Epoch 9, batch 2070: loss=0.1316247433423996
# Epoch 9, batch 2080: loss=0.13112865388393402
# Epoch 9, batch 2090: loss=0.0844184011220932
# Epoch 9, batch 2100: loss=0.138869971036911
# Epoch 9, batch 2110: loss=0.10728874802589417
# Epoch 9, batch 2120: loss=0.14585331082344055
# Epoch 9, batch 2130: loss=0.11786653101444244
# Epoch 9, batch 2140: loss=0.10463519394397736
# Epoch 9, batch 2150: loss=0.08992050588130951
# Epoch 9, batch 2160: loss=0.10435325652360916
# Epoch 9, batch 2170: loss=0.1277175396680832
#
#
# KESt'My;
#
# Hy Loy'r LL SA'b'''L'yoondre, 'br tta tarbet'd tfoirm tavran, ke fed are tanrshind spe falres
# DY!
# And DIUSHe tart al tharn'll, taft, I dil tof,
# By fiyofreu ceicens, Anoull'der eolak, mo cinott As Memoy wa,
# Bomat by, ndofsir
# Ma, friclraint are Im, kmalen yokerot ak ribrenty an bea bays noy all fond fse,
# BI har iy touly waist:
# P preislariey foblag, wig ov,e
# Mand inber thake Rouraren pur I:
# A orith mid lo har thear wif tiver the wu
# By hin theror ouree wf ESerifno mera hes.
# CDIS,
# MIOSP:
# NI arnuris
#
# Sou thay hine. Rat hero hith I sere, mean kamepr phas farderele sar he
# And beatth ero berevolestil we ID bre nit gn charitombe lor ma,
# I wariel Jou bie tor a'd Bonllyokipr sor mino INo ve fol,
# in live!
# TL, IOLWily ololllre,
#
# Woor fif win tl
# Afad malis, thu sa, dir Evemen
# Aner IAs tha uind ter an momt wink fnly.
#
# P'ENNEO:
# SNole, INar spallld fre.'NN IOP tod urAf
# I'.
#
#
# LONENINRLINLLFHD:
# PULLORPRORKILOLRINIRKIRKINRKIRRKIRKKIDPKIKKKKKKDKDDDKKDKKDKDKnDKKDKKrDrxKKDDDKKKDKKKKDDDDnKKDDDDDDDDDD
#
# Epoch 10, batch 0: loss=0.10691279917955399
# Epoch 10, batch 10: loss=0.08623287826776505
# Epoch 10, batch 20: loss=0.08576542139053345
# Epoch 10, batch 30: loss=0.10295268893241882
# Epoch 10, batch 40: loss=0.1048278883099556
# Epoch 10, batch 50: loss=0.10370226204395294
# Epoch 10, batch 60: loss=0.09437140077352524
# Epoch 10, batch 70: loss=0.13037575781345367
# Epoch 10, batch 80: loss=0.09703941643238068
# Epoch 10, batch 90: loss=0.07490043342113495
# Epoch 10, batch 100: loss=0.09046528488397598
# Epoch 10, batch 110: loss=0.09281659871339798
# Epoch 10, batch 120: loss=0.12086888402700424
# Epoch 10, batch 130: loss=0.12257538735866547
# Epoch 10, batch 140: loss=0.10467097163200378
# Epoch 10, batch 150: loss=0.09077969193458557
# Epoch 10, batch 160: loss=0.10215815156698227
# Epoch 10, batch 170: loss=0.11631982773542404
# Epoch 10, batch 180: loss=0.10911799967288971
# Epoch 10, batch 190: loss=0.11581819504499435
# Epoch 10, batch 200: loss=0.08169790357351303
# Epoch 10, batch 210: loss=0.13178367912769318
# Epoch 10, batch 220: loss=0.10135377943515778
# Epoch 10, batch 230: loss=0.10426214337348938
# Epoch 10, batch 240: loss=0.11443798243999481
# Epoch 10, batch 250: loss=0.08487033098936081
# Epoch 10, batch 260: loss=0.10097865760326385
# Epoch 10, batch 270: loss=0.09109008312225342
# Epoch 10, batch 280: loss=0.11754044890403748
# Epoch 10, batch 290: loss=0.11422590911388397
# Epoch 10, batch 300: loss=0.10012839734554291
# Epoch 10, batch 310: loss=0.09410946816205978
# Epoch 10, batch 320: loss=0.1475888341665268
# Epoch 10, batch 330: loss=0.09728287160396576
# Epoch 10, batch 340: loss=0.080388642847538
# Epoch 10, batch 350: loss=0.11834178119897842
# Epoch 10, batch 360: loss=0.12710711359977722
# Epoch 10, batch 370: loss=0.11743075400590897
# Epoch 10, batch 380: loss=0.10194139927625656
# Epoch 10, batch 390: loss=0.10479360818862915
# Epoch 10, batch 400: loss=0.0874718576669693
# Epoch 10, batch 410: loss=0.10111062973737717
# Epoch 10, batch 420: loss=0.11274509131908417
# Epoch 10, batch 430: loss=0.07658021152019501
# Epoch 10, batch 440: loss=0.10274539142847061
# Epoch 10, batch 450: loss=0.09726767987012863
# Epoch 10, batch 460: loss=0.10710368305444717
# Epoch 10, batch 470: loss=0.12393152713775635
# Epoch 10, batch 480: loss=0.12270050495862961
# Epoch 10, batch 490: loss=0.0853247418999672
#
#
# KIVa? QRDy-byby;'--;
#
#
#
#
#
# PA'A!:
# EOLCOPUSaur, hour, woy froft Int letre thtarindin ishe bfingre.
#
# FIURery?:
# TLI:
# Arimyang mily dom rom tak marat nont owan thu mance far-urend oor the lyoforny,
# As m, nomfaimy a whblit, anteast we'lle tanst se chally.
# Thtald, wiat tas lf ofu, mandratles?ar, d Ho -ores wartr:
#
# Bapltind tilld di sso the me tove,
# AnwZNo foly ty ay,ld a
# Anow arls sian mant riceirm ish:
# Roplleson; nabt hzyCalelizerlly.
#
# GRIZARined, the low Eole land IOr on's.
# Wherti til parry, at yothe yur an kis ny abeforG anye s.
# Try anreeno arz tor shadr corare'cha't: soversll birem bandt y tquexe
# Tor.
# XITracuve he farsurourre benadlan cofrd qulelor.
# -eloldrt Tay? mir thad lkimy IU ya cant., yors
# P:
# lltagnice tent athe preng that t vefren yomte cofloot Cor dry,
#
# OLANom, tram ar twily,
# I sthe sackllle soalllacstre bools nots anke anelever brod ere morath uon!
# Odr nke ollro. mothest mtss
# Einp theanoo thed cou taverer! hley.
#
# DhTEROUNINGur? ange?
# We? por?
# N mafornorr an blaar.
# Erdint:
# Seyonll
#
# Epoch 10, batch 500: loss=0.09706366062164307
# Epoch 10, batch 510: loss=0.10150189697742462
# Epoch 10, batch 520: loss=0.08939989656209946
# Epoch 10, batch 530: loss=0.10934195667505264
# Epoch 10, batch 540: loss=0.14701007306575775
# Epoch 10, batch 550: loss=0.10650353133678436
# Epoch 10, batch 560: loss=0.09094186872243881
# Epoch 10, batch 570: loss=0.12249891459941864
# Epoch 10, batch 580: loss=0.10090648382902145
# Epoch 10, batch 590: loss=0.09629032760858536
# Epoch 10, batch 600: loss=0.09236118942499161
# Epoch 10, batch 610: loss=0.09544213861227036
# Epoch 10, batch 620: loss=0.09996864944696426
# Epoch 10, batch 630: loss=0.12347052991390228
# Epoch 10, batch 640: loss=0.09114306420087814
# Epoch 10, batch 650: loss=0.10367996990680695
# Epoch 10, batch 660: loss=0.08247555047273636
# Epoch 10, batch 670: loss=0.13025076687335968
# Epoch 10, batch 680: loss=0.12253721058368683
# Epoch 10, batch 690: loss=0.10507067292928696
# Epoch 10, batch 700: loss=0.09913317114114761
# Epoch 10, batch 710: loss=0.10174349695444107
# Epoch 10, batch 720: loss=0.09349483251571655
# Epoch 10, batch 730: loss=0.11549112200737
# Epoch 10, batch 740: loss=0.07941007614135742
# Epoch 10, batch 750: loss=0.09650389850139618
# Epoch 10, batch 760: loss=0.12212315201759338
# Epoch 10, batch 770: loss=0.11780919134616852
# Epoch 10, batch 780: loss=0.10518097877502441
# Epoch 10, batch 790: loss=0.12045511603355408
# Epoch 10, batch 800: loss=0.1022237166762352
# Epoch 10, batch 810: loss=0.11632266640663147
# Epoch 10, batch 820: loss=0.0738227441906929
# Epoch 10, batch 830: loss=0.13117122650146484
# Epoch 10, batch 840: loss=0.11390883475542068
# Epoch 10, batch 850: loss=0.10900826752185822
# Epoch 10, batch 860: loss=0.0893949419260025
# Epoch 10, batch 870: loss=0.09100233018398285
# Epoch 10, batch 880: loss=0.13034358620643616
# Epoch 10, batch 890: loss=0.11664289981126785
# Epoch 10, batch 900: loss=0.0843251645565033
# Epoch 10, batch 910: loss=0.0986509919166565
# Epoch 10, batch 920: loss=0.09667146950960159
# Epoch 10, batch 930: loss=0.10395462810993195
# Epoch 10, batch 940: loss=0.1040014773607254
# Epoch 10, batch 950: loss=0.08446300029754639
# Epoch 10, batch 960: loss=0.12260747700929642
# Epoch 10, batch 970: loss=0.13057002425193787
# Epoch 10, batch 980: loss=0.11309216916561127
# Epoch 10, batch 990: loss=0.11217159777879715
#
#
# HETHaL My;
# Noy-' '' ''''''''''''e''e' h''t''''''e'''''''''''''''''''''''''''''''''''''C'''''''''''''''''''''L'''''L''''''t''''''''''''''''''s'''''''''''''''''''''L''''''''''''''L'n''''i'''''''''''''''''''''''''''''''''''''F''''''''''''''''''''L''''''''''''' ''''''p'''''''''
# '''''''''''''''''''''p''''''''''L'''''''''''''''''''''''p'''''''''''''''''''''''''''''''''''''''''''''''':''''''''''''''''''''';''''''' ''en;''''''''''''''e'''e''''''''''''''''''en''''''''''''L'''L'''''''''''''''''Sr'''''''''''L'''L'''''''''''''''''''''''''''''''e''''''''''''''''''''''''''''''''''''p'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''' ''''''''''''''l':''''','''''''L''''''N'''''''''''''''''' ''''''''F''''''''''''''''p'''''''''''''''''''''''''''''''''''''''''''''''''''''''''''L'''F'''''''''''''''F'''L''''''' '''''''L''''''''F''''? '''''''''''''''''''''''''''''n'''''''' y''''''''''''''''''''''''''''''''''''z '''''''F'''''''''''''''''''''L'''''''''''''''''''F''''''''''L''''''''
# ''L''''''''''''
#
# Epoch 10, batch 1000: loss=0.1384771168231964
# Epoch 10, batch 1010: loss=0.10286232084035873
# Epoch 10, batch 1020: loss=0.09470562636852264
# Epoch 10, batch 1030: loss=0.10851326584815979
# Epoch 10, batch 1040: loss=0.1013568788766861
# Epoch 10, batch 1050: loss=0.08823417872190475
# Epoch 10, batch 1060: loss=0.08804066479206085
# Epoch 10, batch 1070: loss=0.09654281288385391
# Epoch 10, batch 1080: loss=0.10469317436218262
# Epoch 10, batch 1090: loss=0.12785258889198303
# Epoch 10, batch 1100: loss=0.09842812269926071
# Epoch 10, batch 1110: loss=0.10992546379566193
# Epoch 10, batch 1120: loss=0.1040729433298111
# Epoch 10, batch 1130: loss=0.0929473266005516
# Epoch 10, batch 1140: loss=0.1085781678557396
# Epoch 10, batch 1150: loss=0.1041044294834137
# Epoch 10, batch 1160: loss=0.09801608324050903
# Epoch 10, batch 1170: loss=0.0891493409872055
# Epoch 10, batch 1180: loss=0.14648443460464478
# Epoch 10, batch 1190: loss=0.11784923821687698
# Epoch 10, batch 1200: loss=0.11103818565607071
# Epoch 10, batch 1210: loss=0.10920605808496475
# Epoch 10, batch 1220: loss=0.12556223571300507
# Epoch 10, batch 1230: loss=0.10178381204605103
# Epoch 10, batch 1240: loss=0.11184096336364746
# Epoch 10, batch 1250: loss=0.08902391791343689
# Epoch 10, batch 1260: loss=0.077861487865448
# Epoch 10, batch 1270: loss=0.10009228438138962
# Epoch 10, batch 1280: loss=0.12209970504045486
# Epoch 10, batch 1290: loss=0.10207259654998779
# Epoch 10, batch 1300: loss=0.11219961941242218
# Epoch 10, batch 1310: loss=0.09893865883350372
# Epoch 10, batch 1320: loss=0.11025894433259964
# Epoch 10, batch 1330: loss=0.10568711161613464
# Epoch 10, batch 1340: loss=0.10921406000852585
# Epoch 10, batch 1350: loss=0.11069221794605255
# Epoch 10, batch 1360: loss=0.11146409809589386
# Epoch 10, batch 1370: loss=0.10709252953529358
# Epoch 10, batch 1380: loss=0.10379897058010101
# Epoch 10, batch 1390: loss=0.13057497143745422
# Epoch 10, batch 1400: loss=0.11017557978630066
# Epoch 10, batch 1410: loss=0.09914395958185196
# Epoch 10, batch 1420: loss=0.11715923249721527
# Epoch 10, batch 1430: loss=0.11151456832885742
# Epoch 10, batch 1440: loss=0.11388698220252991
# Epoch 10, batch 1450: loss=0.10103258490562439
# Epoch 10, batch 1460: loss=0.09957130998373032
# Epoch 10, batch 1470: loss=0.08996832370758057
# Epoch 10, batch 1480: loss=0.09381857514381409
# Epoch 10, batch 1490: loss=0.10604122281074524
#
#
# Cly;
# Beprny'p ble'
# '''''''''''''' FeFe.'e'im 't '
#
# Fiquri':
# No''.
# Spille,'de ore,d I yod asspe witheu id fe
#
# ued,
# I sf de. mfir aroveis to be ile so ms wil ret moa be the vian
# Sis tr you genevamsth onte oman peldere wast;
#
# es akiethene; fiepaveey tem? ar mer med che Kibemer cfere meand wipe urreintloom, me
# my freeancattou?
# The muptann tomesteee ho To ad pl imover,epslam,
# Aard tofpe, lipdet blee-se-cos of shisV;
#  che opat ils mie,
# P's wawive kise he Aa awe at tode ou doclrd imear atond te qusle rome tod om mor;
#  have; mue;
# It brobhar bry dedie.
# -oug hime nerometeel soot be co-l fiwe seefve d fie
# Btd ifof VifD:
# Seneraine mas heice vere to! werded Lool' he Dwrnd ser.
#
#
# PTHESTound to qunt gonted mele theth Im thue n-lurd hithle coo me.
#
# enighet,d
#  hamy hode th vador, ve cocitre dot sf mlillave, fly bak; to set nat ow I ndoue Ofobur, my,
# Duse weat hesire phe merers food t
# ot imadstre the mart nows der cf pimD any pe yovave!,
# Ke permo at fire.
# Hdu kerdgowced porou yo 'see mod.
#
# Nmes wirech i
#
# Epoch 10, batch 1500: loss=0.09237022697925568
# Epoch 10, batch 1510: loss=0.0961342602968216
# Epoch 10, batch 1520: loss=0.0988619402050972
# Epoch 10, batch 1530: loss=0.11558675020933151
# Epoch 10, batch 1540: loss=0.13567057251930237
# Epoch 10, batch 1550: loss=0.09780991822481155
# Epoch 10, batch 1560: loss=0.08899593353271484
# Epoch 10, batch 1570: loss=0.12079041451215744
# Epoch 10, batch 1580: loss=0.07985503226518631
# Epoch 10, batch 1590: loss=0.12738625705242157
# Epoch 10, batch 1600: loss=0.08632836490869522
# Epoch 10, batch 1610: loss=0.086403988301754
# Epoch 10, batch 1620: loss=0.12826505303382874
# Epoch 10, batch 1630: loss=0.10009333491325378
# Epoch 10, batch 1640: loss=0.0892241895198822
# Epoch 10, batch 1650: loss=0.10073813050985336
# Epoch 10, batch 1660: loss=0.09426494687795639
# Epoch 10, batch 1670: loss=0.08805989474058151
# Epoch 10, batch 1680: loss=0.10436613857746124
# Epoch 10, batch 1690: loss=0.10362608730792999
# Epoch 10, batch 1700: loss=0.09104850143194199
# Epoch 10, batch 1710: loss=0.08464515954256058
# Epoch 10, batch 1720: loss=0.12145156413316727
# Epoch 10, batch 1730: loss=0.10718700289726257
# Epoch 10, batch 1740: loss=0.08832041174173355
# Epoch 10, batch 1750: loss=0.09867321699857712
# Epoch 10, batch 1760: loss=0.09172894060611725
# Epoch 10, batch 1770: loss=0.10212685912847519
# Epoch 10, batch 1780: loss=0.1241234838962555
# Epoch 10, batch 1790: loss=0.13614194095134735
# Epoch 10, batch 1800: loss=0.10614828020334244
# Epoch 10, batch 1810: loss=0.10140498727560043
# Epoch 10, batch 1820: loss=0.09377444535493851
# Epoch 10, batch 1830: loss=0.10054086148738861
# Epoch 10, batch 1840: loss=0.094208724796772
# Epoch 10, batch 1850: loss=0.10183268785476685
# Epoch 10, batch 1860: loss=0.11521770060062408
# Epoch 10, batch 1870: loss=0.1157093420624733
# Epoch 10, batch 1880: loss=0.09181179106235504
# Epoch 10, batch 1890: loss=0.12157097458839417
# Epoch 10, batch 1900: loss=0.0974377766251564
# Epoch 10, batch 1910: loss=0.10236242413520813
# Epoch 10, batch 1920: loss=0.13018807768821716
# Epoch 10, batch 1930: loss=0.11209375411272049
# Epoch 10, batch 1940: loss=0.11088500916957855
# Epoch 10, batch 1950: loss=0.10073605924844742
# ...
# Bs enet h
#
# Epoch 18, batch 2000: loss=0.07644262909889221
# Epoch 18, batch 2010: loss=0.0578349232673645
# Epoch 18, batch 2020: loss=0.07657624781131744
# Epoch 18, batch 2030: loss=0.07446350157260895
# Epoch 18, batch 2040: loss=0.0812491923570633
# Epoch 18, batch 2050: loss=0.08441322296857834
# Epoch 18, batch 2060: loss=0.09069010615348816
# Epoch 18, batch 2070: loss=0.07706505805253983
# Epoch 18, batch 2080: loss=0.09443824738264084
# Epoch 18, batch 2090: loss=0.09440343081951141
# Epoch 18, batch 2100: loss=0.07567282766103745
# Epoch 18, batch 2110: loss=0.08199790120124817
# Epoch 18, batch 2120: loss=0.07735724002122879
# Epoch 18, batch 2130: loss=0.08067622035741806
# Epoch 18, batch 2140: loss=0.07980093359947205
# Epoch 18, batch 2150: loss=0.07623773068189621
# Epoch 18, batch 2160: loss=0.0752231553196907
# Epoch 18, batch 2170: loss=0.07378988713026047
#
#
# KEm; Warfly? Sdve; Bld SSd?''A'G hew!
# Sor!
# G ORIO:
# Thaed'elto'd ghil''d yoctans.'s ind:
# Thep dup'd de,?
# AnY: dee due ta tetak, e apl Oaste,-om!
# A'd Irts
#
# PEO:
# GWher, whellw chat, Your ponge,
# snet itast in wlue se wwate
# A, d's ande ver well.
#
# CONSTINA:
# Thewse st'les dves anse, sielt one ha ing st, ghen: shoupe dre
# Hes heay cnoweer he wow I sustak's lena'sen!:
# T:
# Toe, ald, ist uf: tousce no tour earuton, onuss.
#
# USTARONT:
# A it lour: nin's mes llanHe, fo hes eust congens, bevas e my?
#
# Wis my hesser: ins, enat! no whive
# As ss sofsalmy:
# Ance, keat diwereell, neo, the meatles bewn, les?
#
# IORARER:
# AP:
# Te I gast ta mous:
# Tangelr tote anies, me my llie trime ben:
# Ad yall a'ld as hake fed how, ghad' wea dobe;
# AEou Thas hale on ste,-mare wo'll!
#
# M'Thesy. nalled, gon davesute I Henca in
# An GL:
# The, Manght' thy at she liss nhe.
# Harster?
#
# BROTHENTO:
# The me mast youn. beny. s?
# INAR:
# Heir, I rast, aure, I and and tha:
# Theet naven, shachis a wnde-e levagh sath sher woth bend Keixe:
# NINT:'spur, thase't
#
# Epoch 19, batch 0: loss=0.0912933349609375
# Epoch 19, batch 10: loss=0.06888429075479507
# Epoch 19, batch 20: loss=0.07236966490745544
# Epoch 19, batch 30: loss=0.06511649489402771
# Epoch 19, batch 40: loss=0.0667499229311943
# Epoch 19, batch 50: loss=0.08212971687316895
# Epoch 19, batch 60: loss=0.06667880713939667
# Epoch 19, batch 70: loss=0.07325703650712967
# Epoch 19, batch 80: loss=0.06341249495744705
# Epoch 19, batch 90: loss=0.06596720963716507
# Epoch 19, batch 100: loss=0.06837749481201172
# Epoch 19, batch 110: loss=0.08912132680416107
# Epoch 19, batch 120: loss=0.06165669113397598
# Epoch 19, batch 130: loss=0.105765201151371
# Epoch 19, batch 140: loss=0.08946285396814346
# Epoch 19, batch 150: loss=0.08146160840988159
# Epoch 19, batch 160: loss=0.07562246918678284
# Epoch 19, batch 170: loss=0.06910497695207596
# Epoch 19, batch 180: loss=0.06796162575483322
# Epoch 19, batch 190: loss=0.07345464080572128
# Epoch 19, batch 200: loss=0.07983160763978958
# Epoch 19, batch 210: loss=0.05950671061873436
# Epoch 19, batch 220: loss=0.08034597337245941
# Epoch 19, batch 230: loss=0.08326166123151779
# Epoch 19, batch 240: loss=0.08956664055585861
# Epoch 19, batch 250: loss=0.08337124437093735
# Epoch 19, batch 260: loss=0.06676067411899567
# Epoch 19, batch 270: loss=0.06779536604881287
# Epoch 19, batch 280: loss=0.09073251485824585
# Epoch 19, batch 290: loss=0.08251433074474335
# Epoch 19, batch 300: loss=0.06790489703416824
# Epoch 19, batch 310: loss=0.08530730754137039
# Epoch 19, batch 320: loss=0.076063372194767
# Epoch 19, batch 330: loss=0.06823495775461197
# Epoch 19, batch 340: loss=0.07308445125818253
# Epoch 19, batch 350: loss=0.08129279315471649
# Epoch 19, batch 360: loss=0.06807157397270203
# Epoch 19, batch 370: loss=0.0681738331913948
# Epoch 19, batch 380: loss=0.05488624423742294
# Epoch 19, batch 390: loss=0.08881715685129166
# Epoch 19, batch 400: loss=0.07222507148981094
# Epoch 19, batch 410: loss=0.06022519990801811
# Epoch 19, batch 420: loss=0.06889617443084717
# Epoch 19, batch 430: loss=0.05936198681592941
# Epoch 19, batch 440: loss=0.0828956812620163
# Epoch 19, batch 450: loss=0.07220917195081711
# Epoch 19, batch 460: loss=0.06938612461090088
# Epoch 19, batch 470: loss=0.08276044577360153
# Epoch 19, batch 480: loss=0.09018196910619736
# Epoch 19, batch 490: loss=0.07532934844493866
#
#
# HUStAEm My;
# LL E'
# M''
# A'
# L'''''ngeroren juetl. hand.'' dire:
# Lou lapper cithee thiw your of these hon thang on ghifer's she hy whall stau gherld
# Thar gnt.
# tred The the dand I d mass gope thaw fry.
#
# Thoun wisch I ho berakpe d.
#
# TRETienge thy dom ar noed, why loakelow, urow-bunie tr a? Corusene serenom arars, ow than hephure theod an sengre hot wim ate vourllore seris yoawn.
# A tweow ole rromver dit yoult bar whary
# Malit Cret witr dratoury Card mf arie. an drfirmell rerrines then then the gerere fond inereer: det theny sou et eat, ine of your the hu araith:
# Sarthan hof hure sen'ther erand ord?
# NGLO:
# She:
# I the be ay nethen Oreeen hie fohe onk thame on in ghithy whore fer sore hough st. od wfard berere:
# An mawe da bea the foverte sfotilerr, thang thy bury alfur se greerar.
# The drake med avell sere thee to thar, arer wererange the ha aretheerr the
# The f owire the one ore e.-
# Fewe Gsen:
# Henpe ghod: nou fore Veadoniche, wle, I sure ovitn wown oupt butr onpe mant, yonch, withre hu goo dergrs b
#
# Epoch 19, batch 500: loss=0.07423550635576248
# Epoch 19, batch 510: loss=0.07073277980089188
# Epoch 19, batch 520: loss=0.10396203398704529
# Epoch 19, batch 530: loss=0.05843681842088699
# Epoch 19, batch 540: loss=0.07854955643415451
# Epoch 19, batch 550: loss=0.08911743015050888
# Epoch 19, batch 560: loss=0.07791035622358322
# Epoch 19, batch 570: loss=0.0732860192656517
# Epoch 19, batch 580: loss=0.07172268629074097
# Epoch 19, batch 590: loss=0.06398128718137741
# Epoch 19, batch 600: loss=0.06757015734910965
# Epoch 19, batch 610: loss=0.08825618028640747
# Epoch 19, batch 620: loss=0.07465369254350662
# Epoch 19, batch 630: loss=0.08867256343364716
# Epoch 19, batch 640: loss=0.06725279986858368
# Epoch 19, batch 650: loss=0.08122722804546356
# Epoch 19, batch 660: loss=0.0600665844976902
# Epoch 19, batch 670: loss=0.0725829154253006
# Epoch 19, batch 680: loss=0.06628502160310745
# Epoch 19, batch 690: loss=0.0669509619474411
# Epoch 19, batch 700: loss=0.07828068733215332
# Epoch 19, batch 710: loss=0.10431790351867676
# Epoch 19, batch 720: loss=0.06473476439714432
# Epoch 19, batch 730: loss=0.09232860058546066
# Epoch 19, batch 740: loss=0.06835698336362839
# Epoch 19, batch 750: loss=0.07535886019468307
# Epoch 19, batch 760: loss=0.09333348274230957
# Epoch 19, batch 770: loss=0.08377925306558609
# Epoch 19, batch 780: loss=0.06727919727563858
# Epoch 19, batch 790: loss=0.07772301882505417
# Epoch 19, batch 800: loss=0.0692034587264061
# Epoch 19, batch 810: loss=0.06517532467842102
# Epoch 19, batch 820: loss=0.08618862926959991
# Epoch 19, batch 830: loss=0.0820581391453743
# Epoch 19, batch 840: loss=0.07588353753089905
# Epoch 19, batch 850: loss=0.07100231200456619
# Epoch 19, batch 860: loss=0.06647367030382156
# Epoch 19, batch 870: loss=0.09378544241189957
# Epoch 19, batch 880: loss=0.08361261337995529
# Epoch 19, batch 890: loss=0.08687543869018555
# Epoch 19, batch 900: loss=0.08814992755651474
# Epoch 19, batch 910: loss=0.06482145935297012
# Epoch 19, batch 920: loss=0.06720840930938721
# Epoch 19, batch 930: loss=0.07949744910001755
# Epoch 19, batch 940: loss=0.08049589395523071
# Epoch 19, batch 950: loss=0.08350138366222382
# Epoch 19, batch 960: loss=0.07955915480852127
# Epoch 19, batch 970: loss=0.09864303469657898
# Epoch 19, batch 980: loss=0.08350960910320282
# Epoch 19, batch 990: loss=0.08157465606927872
#
#
# KENt; My!
# LA Llo; an' L a;
# A'A' ffit ing the cain, op gror if he-ngery the lin's honthavee
# than of dingertetrn
# Her wink ruiocp so hf worty ounshe,
# An werer tare proffeig hrod,
# Mainging,
# I spunghy hid; of our wroncone an m's berthomy ane ig ain!
# Of bly heshedrsir vurle spancyon
# Lelkess.
#
# EUSIN sy her Bumy haveanat hin thar pilew, ur,
# Thith of drie opr thou or'dighte to, ande mad ble to drightou hes hing
# Nodisest,
# And inth, wind un parshe ny ilpingeslag,
# Mothseks inger liveire nis couns home.
# Gik ntor lea'e.
#
# ALUGLELLES:
# TISThy tal no vit thicern thereming ith;
# Hld ghich'ds in this fay ari ga oferighe
# To the hinger, o werre! mant her ant erofer
# Maiy; inguben has feres of sione bliporpth her
# Uneiaks ed surde te-intodu shingabllai?
#
# mant, follily; as chenrel-sins mier of inreanoinppe nes?
# !
# EY hy moreall ack esse lenjenketl of shre.
# Wemin, heme the to thon inte the gromsearinghe:
# And noevisk it wimgrtenouse dor hfrubins buer dibe led phinor?
# Bsikeall tho rownaly my, I thaplinkpr a le'd
# Tha
#
# Epoch 19, batch 1000: loss=0.08686438202857971
# Epoch 19, batch 1010: loss=0.08530744910240173
# Epoch 19, batch 1020: loss=0.07073882222175598
# Epoch 19, batch 1030: loss=0.06305678933858871
# Epoch 19, batch 1040: loss=0.08470415323972702
# Epoch 19, batch 1050: loss=0.06423304975032806
# Epoch 19, batch 1060: loss=0.07974503934383392
# Epoch 19, batch 1070: loss=0.07034847140312195
# Epoch 19, batch 1080: loss=0.07713565230369568
# Epoch 19, batch 1090: loss=0.06716255843639374
# Epoch 19, batch 1100: loss=0.08901116997003555
# Epoch 19, batch 1110: loss=0.10606145113706589
# Epoch 19, batch 1120: loss=0.10435831546783447
# Epoch 19, batch 1130: loss=0.08638040721416473
# Epoch 19, batch 1140: loss=0.07208161056041718
# Epoch 19, batch 1150: loss=0.09762449562549591
# Epoch 19, batch 1160: loss=0.08926879614591599
# Epoch 19, batch 1170: loss=0.08653408288955688
# Epoch 19, batch 1180: loss=0.07429865747690201
# Epoch 19, batch 1190: loss=0.0914202332496643
# Epoch 19, batch 1200: loss=0.07987046986818314
# Epoch 19, batch 1210: loss=0.08375541865825653
# Epoch 19, batch 1220: loss=0.07321036607027054
# Epoch 19, batch 1230: loss=0.06700699031352997
# Epoch 19, batch 1240: loss=0.06521645188331604
# Epoch 19, batch 1250: loss=0.07557697594165802
# Epoch 19, batch 1260: loss=0.06492471694946289
# Epoch 19, batch 1270: loss=0.09340488910675049
# Epoch 19, batch 1280: loss=0.09667600691318512
# Epoch 19, batch 1290: loss=0.07858815044164658
# Epoch 19, batch 1300: loss=0.082500159740448
# Epoch 19, batch 1310: loss=0.07863767445087433
# Epoch 19, batch 1320: loss=0.07406150549650192
# Epoch 19, batch 1330: loss=0.08480338752269745
# Epoch 19, batch 1340: loss=0.07310876995325089
# Epoch 19, batch 1350: loss=0.07326002418994904
# Epoch 19, batch 1360: loss=0.08434680104255676
# Epoch 19, batch 1370: loss=0.08843550086021423
# Epoch 19, batch 1380: loss=0.07347098737955093
# Epoch 19, batch 1390: loss=0.0894872173666954
# Epoch 19, batch 1400: loss=0.0810094103217125
# Epoch 19, batch 1410: loss=0.06212972104549408
# Epoch 19, batch 1420: loss=0.07957839965820312
# Epoch 19, batch 1430: loss=0.08717051148414612
# Epoch 19, batch 1440: loss=0.07765693962574005
# Epoch 19, batch 1450: loss=0.08502793312072754
# Epoch 19, batch 1460: loss=0.07772980630397797
# Epoch 19, batch 1470: loss=0.08965976536273956
# Epoch 19, batch 1480: loss=0.08384711295366287
# Epoch 19, batch 1490: loss=0.07883141189813614
#
#
# KbKa? HIfod
#
# Brlll SSSSSSAN'A''d 'e yowe,
# HE sy.
#
# RSINGRIGLITHAR:
# He wend Rox:
# HULeat:
# his ghe fus of yos, hat. the chichu
# Bent, Couthe sa-t cenicsy. Hemy, wirt, thalve Mou fo'st to mnom.
# MINHETHANTHANEm, hay I le his etowenell:
# Ad, st sp't send, thepigh singast hurl anthe testand test cougheld gell soug, ist lod stan gnils:
# Mast gowe eay gads'ss.
# Coud titsest tatl, s of the keell?
# E the tle sweit, be ny noutt, woure un hagust gepoy,
# Tapedty, othod Cy suet of inter?
# Thou te tils to abung s.
#
# RUMENTET:
# The beat art hit ce neen tuct thut ne.
#
# GRICHAS:
# Et the not ing. to thais erting; yom s I lamt sls cage t west ainw Mou brows wirt say:
# Bnde!
# We sollser, wak thyes I ge afroth,
# Thu to ther thut gout:
# Ha wy fagn spaw, Gligse an to'd dig,
# Fisthenan I bloy hery, thingre go'gs tred
# Bat IT tf ther, But fofamy corle in thos;
# Tf ind Pross us sterre we! ke An the shelve.
#
# ANTINTy, ly'. ANZ:
# I shat I foup twatil is to'd kemaghe wey malt? Le to sf keed.?
#
# KENVONVEN:
#
# BONG POREw'm, cornespay'O:
# g, i
#
# Epoch 19, batch 1500: loss=0.0653715431690216
# Epoch 19, batch 1510: loss=0.09516310691833496
# Epoch 19, batch 1520: loss=0.07234131544828415
# Epoch 19, batch 1530: loss=0.09946873784065247
# Epoch 19, batch 1540: loss=0.07389762252569199
# Epoch 19, batch 1550: loss=0.08340373635292053
# Epoch 19, batch 1560: loss=0.062178779393434525
# Epoch 19, batch 1570: loss=0.07558950781822205
# Epoch 19, batch 1580: loss=0.08162853866815567
# Epoch 19, batch 1590: loss=0.07042673230171204
# Epoch 19, batch 1600: loss=0.06848028302192688
# Epoch 19, batch 1610: loss=0.0775875598192215
# Epoch 19, batch 1620: loss=0.06612566113471985
# Epoch 19, batch 1630: loss=0.0855439305305481
# Epoch 19, batch 1640: loss=0.07701350003480911
# Epoch 19, batch 1650: loss=0.07675790041685104
# Epoch 19, batch 1660: loss=0.10069811344146729
# Epoch 19, batch 1670: loss=0.0904831513762474
# Epoch 19, batch 1680: loss=0.08752896636724472
# Epoch 19, batch 1690: loss=0.08078112453222275
# Epoch 19, batch 1700: loss=0.0679987445473671
# Epoch 19, batch 1710: loss=0.0674717053771019
# Epoch 19, batch 1720: loss=0.0771101638674736
# Epoch 19, batch 1730: loss=0.09097348153591156
# Epoch 19, batch 1740: loss=0.07614487409591675
# Epoch 19, batch 1750: loss=0.09250508248806
# Epoch 19, batch 1760: loss=0.0725913792848587
# Epoch 19, batch 1770: loss=0.0709199458360672
# Epoch 19, batch 1780: loss=0.08332565426826477
# Epoch 19, batch 1790: loss=0.07543054223060608
# Epoch 19, batch 1800: loss=0.07848503440618515
# Epoch 19, batch 1810: loss=0.08825932443141937
# Epoch 19, batch 1820: loss=0.05516355484724045
# Epoch 19, batch 1830: loss=0.07193302363157272
# Epoch 19, batch 1840: loss=0.07133432477712631
# Epoch 19, batch 1850: loss=0.0707290843129158
# Epoch 19, batch 1860: loss=0.08786412328481674
# Epoch 19, batch 1870: loss=0.08913002908229828
# Epoch 19, batch 1880: loss=0.08411311358213425
# Epoch 19, batch 1890: loss=0.06619276851415634
# Epoch 19, batch 1900: loss=0.08550189435482025
# Epoch 19, batch 1910: loss=0.07071609050035477
# Epoch 19, batch 1920: loss=0.07617509365081787
# Epoch 19, batch 1930: loss=0.0946478396654129
# Epoch 19, batch 1940: loss=0.09297148883342743
# Epoch 19, batch 1950: loss=0.06297125667333603
# Epoch 19, batch 1960: loss=0.06468411535024643
# Epoch 19, batch 1970: loss=0.09786437451839447
# Epoch 19, batch 1980: loss=0.05921158939599991
# Epoch 19, batch 1990: loss=0.06963378190994263
#
#
# KEm'
# Bly; Lloflepl SSSpd!
#
# A'A'LOPSSUShy.
#
# MOSSPEORSPSS:
# Sir bushor Simy wofupr: heake moy toad beas than te bnoun--Ant oum mo nosbets?
# TIOLond wob, I eust bakind tunt fontor'd anied,
# Ond wal whtot nom Vofal tou macawnel. ton hor with at.
# To my ARaffrit.
#
# SUENDUCHARETR:
# Bonme, genangigss tomall to apind,
# And aindlond hes ropunnirs be thiagaied.
# Canall tast not ma mo michtamm. and forullam chand oor loste, thoov ny Anod?
# Ay AMI dim is thand fusiknaks As then thean the bo wall osengoun wrigh tligen so this.
#
# IES ES:
# QUCE hom; gor En Edonme.
#
# TEONGSESS:
# 3 bu tho the fo seakin
# Eo that DI melist is thery you casonfe
# Kat I sut havedes if lamfend thit sunly.
#
# TUENARGNES:
# Vorads is youse, Dued.
#
# NDUROTIS: wa'd yad bath I foul well forech wior in-benofinsthet,
# I nop wiftier und hilfilist if mis fiedsh'ent
# Pen'd ait.
#
# NISLUSS:
# OLLCO:
# Coun'st MI het may, mou'lloo mod,
#
# THUKI LINICan:
# Aw homy and I dude bo dovius thaneres
# Bflemary:
# The sou belch-bier;:
# Thu douted arefarwis hote youn And said
#
# Fert
#
# Epoch 19, batch 2000: loss=0.06745783239603043
# Epoch 19, batch 2010: loss=0.08160558342933655
# Epoch 19, batch 2020: loss=0.06874433159828186
# Epoch 19, batch 2030: loss=0.08817212283611298
# Epoch 19, batch 2040: loss=0.08004144579172134
# Epoch 19, batch 2050: loss=0.06023765355348587
# Epoch 19, batch 2060: loss=0.08804460614919662
# Epoch 19, batch 2070: loss=0.10076162219047546
# Epoch 19, batch 2080: loss=0.0837535709142685
# Epoch 19, batch 2090: loss=0.0761304497718811
# Epoch 19, batch 2100: loss=0.08309523016214371
# Epoch 19, batch 2110: loss=0.10446707904338837
# Epoch 19, batch 2120: loss=0.09581051766872406
# Epoch 19, batch 2130: loss=0.06977582722902298
# Epoch 19, batch 2140: loss=0.072220079600811
# Epoch 19, batch 2150: loss=0.08104883134365082
# Epoch 19, batch 2160: loss=0.0827060118317604
# Epoch 19, batch 2170: loss=0.06712903827428818
